# %%
import pandas as pd
import numpy as np

# %%
link='/kaggle/input/usa-housing-listings/housing.csv'
data=pd.read_csv(link)

# %% [markdown]
# **Part 1: Understanding the Dataset**

# %%
data.columns

# %%
data.shape

# %%
data.dtypes

# %%
data.describe()

# %% [markdown]
# **Part 2: Univarite Analysis**

# %%
data[data['price']<0.5e9]['price'].plot(kind='box')

# %%
data['dogs_allowed'].plot(kind='hbar')
